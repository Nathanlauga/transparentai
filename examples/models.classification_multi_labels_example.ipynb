# %% [markdown]
# `models.classification` example for multi labels classification
# -----
#
# ### Load packages

# %%
import transparentai.models.classification as classification
from transparentai.datasets import load_iris

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load & prepare data

# %%
data = load_iris()
X, Y = data.drop(columns='iris plant'), data['iris plant']

# %%
Y = Y.replace({'setosa':0, 'versicolor':1, 'virginica':2})

# %% [markdown]
# Split train test

# %%
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Train classifier

# %%
clf = RandomForestClassifier()
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# Prepare param

# %%
y_true       = Y_train
y_true_valid = Y_valid
y_pred       = clf.predict_proba(X_train)
y_pred_valid = clf.predict_proba(X_valid)

# %% [markdown]
# ### Use `classification.compute_metrics`
#
# List of usable metrics on documentation.
#
# You can add custom metrics ! with
# ```python
# lambda y_true, y_pred: ...
# ```

# %%
metrics = ['accuracy', 'roc_auc_ovr', 'f1_micro', lambda y_true, y_pred: sum(y_true-y_pred)]
classification.compute_metrics(y_true_valid, y_pred_valid, metrics)
# Out:
# {'accuracy': 0.98, 'roc_auc_ovr': 1.0, 'f1_micro': 0.98, 'custom_1': 1}

# %% [markdown]
# ### Use `classification.plot_performance`
#
# #### Only validation

# %%
classification.plot_performance(y_true_valid, y_pred_valid)

# %% [markdown]
# #### Train set and validation

# %%
classification.plot_performance(y_true, y_pred, y_true_valid, y_pred_valid)
